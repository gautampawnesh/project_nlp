# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Importing data

# %%
train_df = pd.read_csv("../datasets/tweet-sentiment-extraction/train.csv")
test_df = pd.read_csv("../datasets/tweet-sentiment-extraction/test.csv")

# %% [markdown]
# ### Data Exploration

# %%
train_df.describe()
# Out:
#             textID                                  text selected_text  \
# count        27481                                 27480         27480
# unique       27481                                 27480         22463
# top     cb774db0d1   I`d have responded, if I were going          good
# freq             1                                     1           199
#
#        sentiment
# count      27481
# unique         3
# top      neutral
# freq       11118

# %%
train_df["text"].describe()
# Out:
# count                                    27480
# unique                                   27480
# top        I`d have responded, if I were going
# freq                                         1
# Name: text, dtype: object

# %%
## Data imbalance check
train_df.sentiment.value_counts()
# Out:
# neutral     11118
# positive     8582
# negative     7781
# Name: sentiment, dtype: int64

# %%
## check text column null row, 
train_df["text"].isnull().values.any()
# Out:
# True

# %%
train_df["text"].isnull().sum()
# Out:
# 1

# %%
# index
train_df[train_df["text"].isnull()].index
# Out:
# Int64Index([314], dtype='int64')

# %%
train_df.iloc[314, :]
# make sense to keep this data
# Out:
# textID           fdb77c3752
# text                    NaN
# selected_text           NaN
# sentiment           neutral
# Name: 314, dtype: object

# %%
train_df["text"].fillna(value="", inplace=True)
train_df["selected_text"].fillna(value="", inplace=True)

# %%
train_df.iloc[314, :]
# Out:
# textID           fdb77c3752
# text
# selected_text
# sentiment           neutral
# Name: 314, dtype: object

# %%
# Convert to lowercase; 
train_df["pre_process"] = train_df["text"].apply(lambda x: " ".join(x.lower() for x in str(x).split()))

# %%
train_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27477  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment  \
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27476                                             d lost  negative
# 27477                                      , don`t force  negative
# 27478                          Yay good for both of you.  positive
# 27479                         But it was worth it  ****.  positive
# 27480  All this flirting going on - The ATG smiles. Y...   neutral
#
#                                              pre_process
# 0                    i`d have responded, if i were going
# 1          sooo sad i will miss you here in san diego!!!
# 2                              my boss is bullying me...
# 3                         what interview! leave me alone
# 4      sons of ****, why couldn`t they put them on th...
# ...                                                  ...
# 27476  wish we could come see u on denver husband los...
# 27477  i`ve wondered about rake to. the client has ma...
# 27478  yay good for both of you. enjoy the break - yo...
# 27479                          but it was worth it ****.
# 27480  all this flirting going on - the atg smiles. y...
#
# [27481 rows x 5 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
train_df['sentiment'] = le.fit_transform(train_df.sentiment.values)

# %%
train_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27477  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text  sentiment  \
# 0                    I`d have responded, if I were going          1
# 1                                               Sooo SAD          0
# 2                                            bullying me          0
# 3                                         leave me alone          0
# 4                                          Sons of ****,          0
# ...                                                  ...        ...
# 27476                                             d lost          0
# 27477                                      , don`t force          0
# 27478                          Yay good for both of you.          2
# 27479                         But it was worth it  ****.          2
# 27480  All this flirting going on - The ATG smiles. Y...          1
#
#                                              pre_process
# 0                                  would responded going
# 1                                sooo sad miss san diego
# 2                                           bos bullying
# 3                                  interview leave alone
# 4                   son could put release already bought
# ...                                                  ...
# 27476  wish could come see u denver husband lost job ...
# 27477  wondered rake client made clear net force devs...
# 27478  yay good enjoy break probably need hectic week...
# 27479                                              worth
# 27480                   flirting going atg smile yay hug
#
# [27481 rows x 5 columns]

# %%
test_df['sentiment'] = le.transform(test_df.sentiment.values)

# %%
test_df
# Out:
#           textID                                               text  sentiment
# 0     f87dea47db  Last session of the day  http://twitpic.com/67ezh          1
# 1     96d74cb729   Shanghai is also really exciting (precisely -...          2
# 2     eee518ae67  Recession hit Veronique Branquinho, she has to...          0
# 3     01082688c6                                        happy bday!          2
# 4     33987a8ee5             http://twitpic.com/4w75p - I like it!!          2
# ...          ...                                                ...        ...
# 3529  e5f0e6ef4b  its at 3 am, im very tired but i can`t sleep  ...          0
# 3530  416863ce47  All alone in this old house again.  Thanks for...          2
# 3531  6332da480c   I know what you mean. My little dog is sinkin...          0
# 3532  df1baec676  _sutra what is your next youtube video gonna b...          2
# 3533  469e15c5a8   http://twitpic.com/4woj2 - omgssh  ang cute n...          2
#
# [3534 rows x 3 columns]

# %% [markdown]
# #### Removing HTML tags and urls

# %%
from bs4 import BeautifulSoup
train_df["pre_process"]=train_df["pre_process"].apply(lambda x: BeautifulSoup(x).get_text())
import re
train_df["pre_process"]=train_df["pre_process"].apply(lambda x: re.sub(r"http\S+", "", x))

# %%
train_df.sample(10)
# Out:
#            textID                                               text  \
# 22543  76dbf5ffbd  Home from Jack`s now, can`t say I`m too happy ...
# 87     cd0d522bb1  His snoring is so annoying n it keeps me from ...
# 4055   fe0c97fb9f    yes but they hate it when we do it...silly boys
# 3632   195605cfe6                         word to yer mother!!   \m/
# 18471  9fe798ecfe  is not liking the online livebox right now. In...
# 9630   2c09848db1  I think Destiny has officially gone crazy... h...
# 1898   700eb9d742  Went out to get groceries...prices are inflati...
# 20443  d665b59814  Up a little.. Good luck to tam and robert who ...
# 8413   c422f33e79   I didn`t read the details so that may be it. ...
# 7762   140dc0f7ab  Going for a ride! Perfect night to go out and ...
#
#                                            selected_text sentiment  \
# 22543                            can`t say I`m too happy  negative
# 87     His snoring is so annoying n it keeps me from ...   neutral
# 4055                                             hate it  negative
# 3632                          word to yer mother!!   \m/   neutral
# 18471                                  Internet is dead.  negative
# 9630                                            hahahaha  positive
# 1898                                           inflating  negative
# 20443                                       Good luck to  positive
# 8413                          it can`t be that exciting.  negative
# 7762   Going for a ride! Perfect night to go out and ...  positive
#
#                                              pre_process
# 22543  home from jack`s now, can`t say i`m too happy ...
# 87     his snoring is so annoying n it keeps me from ...
# 4055     yes but they hate it when we do it...silly boys
# 3632                            word to yer mother!! \m/
# 18471  is not liking the online livebox right now. in...
# 9630   i think destiny has officially gone crazy... h...
# 1898   went out to get groceries...prices are inflati...
# 20443  up a little.. good luck to tam and robert who ...
# 8413   i didn`t read the details so that may be it. s...
# 7762   going for a ride! perfect night to go out and ...

# %% [markdown]
# #### Contraction on text

# %%
def contractions(s):
 s = re.sub(r"won`t", "will not",s)
 s = re.sub(r"would`t", "would not",s)
 s = re.sub(r"could`t", "could not",s)
 s = re.sub(r"\`d", " would",s)
 s = re.sub(r"can\`t", "can not",s)
 s = re.sub(r"n\`t", " not", s)
 s= re.sub(r"\`re", " are", s)
 s = re.sub(r"\`s", " is", s)
 s = re.sub(r"\`ll", " will", s)
 s = re.sub(r"\`t", " not", s)
 s = re.sub(r"\`ve", " have", s)
 s = re.sub(r"\`m", " am", s)
 return s
train_df["pre_process"]=train_df["pre_process"].apply(lambda x:contractions(x))

# %%
train_df.sample(10)
# Out:
#            textID                                               text  \
# 18772  095aa261cb  Uggh everything, I`m sending you!!! I keep sen...
# 4884   3d05361785  about to start work and missing him like crazy...
# 18874  a0235f0820                                        great night
# 6769   9ac16ebcc2  right, so richard marx`s right here waiting is...
# 25250  856c445b1e      may the 4th be with you! HAPPY STAR WARS DAY!
# 22469  0a269cef6e                                How are you today!?
# 2898   ab65c6b83f   TAYLOR! are you back in Nashville now..or LA?...
# 4508   a0a3065378                     _bmac I knooow, I want to sail
# 14296  c8f996b680   exactly  Prime Minister doesn`t need take car...
# 20748  9672b4ee61  GREEN DAY IS PERFORMING ON SNL NEXT WEEK!  sor...
#
#                                            selected_text  sentiment  \
# 18772                                     I suck at life          0
# 4884                            missing him like crazy.I          0
# 18874                                        great night          2
# 6769                                        nauseatingly          0
# 25250                                              HAPPY          2
# 22469                                How are you today!?          1
# 2898                   ? did ya have fun? love ya girly!          2
# 4508                      _bmac I knooow, I want to sail          1
# 14296  exactly  Prime Minister doesn`t need take care...          1
# 20748  sorry, that made me happy and i`m still all di...          1
#
#                                              pre_process
# 18772  uggh everything sending keep sending twitter f...
# 4884   start work missing like crazyi wont seeing til...
# 18874                                        great night
# 6769   right richard marx right waiting really making...
# 25250                          may th happy star war day
# 22469                                              today
# 2898   taylor back nashville la well trip ya fun love...
# 4508                               bmac knooow want sail
# 14296        exactly prime minister need take care issue
# 20748  green day performing snl next week sorry made ...

# %% [markdown]
# #### Removing non-alpha words

# %%
train_df["pre_process"]=train_df["pre_process"].apply(lambda x: " ".join([re.sub("[^A-Za-z]+", "", x) for x in nltk.word_tokenize(x)]))

# %%
train_df.sample(10)
# Out:
#            textID                                               text  \
# 3642   56c95cc7de  Just came back from hanging out with some frie...
# 21306  8c06ec15b8  stealth shopping - got wife b-day present whil...
# 9529   8df54b96bd  Checking out zensify on my iphone. works fine ...
# 10016  d4cc846912   What does it matter? We ALL love you.  Take y...
# 23173  b78e793bcc                        Our Quinn puppy got a sick.
# 13722  7d3f92c5b5  Going lay down, I`ll get up officially @ 1! Ye...
# 15466  4ec6e9138b  Sitting in traffic while my car gets rained on...
# 12524  a3710e95cc                                       Haha thanks.
# 1345   64d352606b   Trying to watch your vids, but the audio has ...
# 16558  0da207081a  _marie better than Hudgens.  OMG our song came...
#
#                                            selected_text sentiment  \
# 3642                                               good.  positive
# 21306  stealth shopping - got wife b-day present whil...   neutral
# 9529   Checking out zensify on my iphone. works fine ...   neutral
# 10016                                   We ALL love you.  positive
# 23173                                              sick.  negative
# 13722                                 Good(night) again!  positive
# 15466       Doesn`t the weather know this is California?  negative
# 12524                                            thanks.  positive
# 1345   Trying to watch your vids, but the audio has b...   neutral
# 16558  _marie better than Hudgens.  OMG our song came...   neutral
#
#                                              pre_process
# 3642   just came back from hanging out with some frie...
# 21306  stealth shopping  got wife bday present while ...
# 9529   checking out zensify on my iphone  works fine ...
# 10016  what does it matter  we all love you  take you...
# 23173                        our quinn puppy got a sick
# 13722  going lay down  i will get up officially    ye...
# 15466  sitting in traffic while my car gets rained on...
# 12524                                       haha thanks
# 1345   trying to watch your vids  but the audio has b...
# 16558  marie better than hudgens  omg our song came o...

# %% [markdown]
# #### Removing extra space b/w words

# %%
train_df["pre_process"]=train_df["pre_process"].apply(lambda x: re.sub(" +", " ", x))

# %%
train_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27477  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment  \
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27476                                             d lost  negative
# 27477                                      , don`t force  negative
# 27478                          Yay good for both of you.  positive
# 27479                         But it was worth it  ****.  positive
# 27480  All this flirting going on - The ATG smiles. Y...   neutral
#
#                                              pre_process
# 0                 i would have responded if i were going
# 1            sooo sad i will miss you here in san diego
# 2                                my boss is bullying me
# 3                          what interview leave me alone
# 4      sons of why could not they put them on the rel...
# ...                                                  ...
# 27476  wish we could come see u on denver husband los...
# 27477  i have wondered about rake to the client has m...
# 27478  yay good for both of you enjoy the break you p...
# 27479                               but it was worth it
# 27480  all this flirting going on the atg smiles yay ...
#
# [27481 rows x 5 columns]

# %% [markdown]
# #### Removing stopwords

# %%
from nltk.corpus import stopwords
stop = stopwords.words("english")
train_df["pre_process"]=train_df["pre_process"].apply(lambda x: " ".join([x for x in x.split() if x not in stop]))

# %%
train_df.sample(10)
# Out:
#            textID                                               text  \
# 4216   c5f1b3ee3e  Not feeling very good at all, why does this ha...
# 24833  fa0983d231   so excited for you and Paris ooh lala  i look...
# 7652   ac4040f7af  watching The Uninvited in my room. Can`t wait ...
# 5864   bbbd57c093              Me too!    need some tour dates stat!
# 3137   a00b2b3fc0              do it and I`ll give you the first hug
# 581    1fce3e2d7b   no bueno.  hollykins needs to feel better asa...
# 19447  cdbe4df131                                     OMG so exctied
# 17864  f7e69e437d  waitin 4 the skool bus soo tired nd still soo ...
# 25575  bb7a8693ea                          Sad to be leaving so soon
# 6625   a244d7aad7              Can`t I mix and match  Dumb drive in!
#
#                                            selected_text sentiment  \
# 4216                                                good  positive
# 24833                                           e lovely  positive
# 7652   watching The Uninvited in my room. Can`t wait ...   neutral
# 5864                Me too!    need some tour dates stat   neutral
# 3137               do it and I`ll give you the first hug  positive
# 581    no bueno.  hollykins needs to feel better asap...   neutral
# 19447                                            exctied  positive
# 17864                                              tired  negative
# 25575                                                Sad  negative
# 6625                                                Dumb  negative
#
#                                              pre_process
# 4216   feeling good happen today days going friends t...
# 24833  excited paris ooh lala look forward knowing lo...
# 7652   watching uninvited room wait go home go deid f...
# 5864                                need tour dates stat
# 3137                                      give first hug
# 581    bueno hollykins needs feel better asap ps miss...
# 19447                                        omg exctied
# 17864  waitin skool bus soo tired nd still soo much w...
# 25575                                   sad leaving soon
# 6625                                mix match dumb drive

# %% [markdown]
# #### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
train_df["pre_process"]=train_df["pre_process"].apply(lambda x: " ".join([lemmatizer.lemmatize(w) for w in nltk.word_tokenize(x)]))

# %%
train_df.sample(10)
# Out:
#            textID                                               text  \
# 15969  64810cb721                                   not just me then
# 6477   8cd4ccab2b                    is having headache and colds...
# 17774  1186f88a11   Oh noooo that sucks  Did you reschedule for a...
# 8103   2eac733725   Good morning hun! I will, promise  Glad you l...
# 21405  e0e093c2e3  ; Re: Home - that`s exactly what I meant... ho...
# 25809  83a44d5505           OK  Just a thought that occured to me...
# 500    18f60b8879   but my bday is JUNE 19.. this is wack... and ...
# 20146  8d7f102cba              Panera is not being nice to my iPhone
# 20896  df783bff1f  Checking out Twitter Trying to find people I k...
# 3885   22ecd73521  So apparently i left my front door wide open b...
#
#                                   selected_text  sentiment  \
# 15969                          not just me then          1
# 6477                       headache and colds..          0
# 17774                                     sucks          0
# 8103                                       Glad          2
# 21405                       uh... I brokt it...          0
# 25809  OK  Just a thought that occured to me...          1
# 500                                       wack.          0
# 20146                            not being nice          0
# 20896                             Unfortunately          0
# 3885                                       Love          2
#
#                                              pre_process
# 15969
# 6477                                       headache cold
# 17774              oh noooo suck reschedule another show
# 8103    good morning hun promise glad like em lovely day
# 21405  home exactly meant home dtown also computer uh...
# 25809                                 ok thought occured
# 500    bday june wack ihavent seen promotion bday par...
# 20146                                 panera nice iphone
# 20896  checking twitter trying find people know unfor...
# 3885   apparently left front door wide open going sho...

# %% [markdown]
# #### Data split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train, Y_test = train_test_split(train_df["pre_process"], train_df["sentiment"], test_size=0.25, random_state=30)

# %%
X_train.shape
# Out:
# (20610,)

# %%
Y_train.shape
# Out:
# (20610,)

# %% [markdown]
# #### Token into features with BOW TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer= TfidfVectorizer()
tf_x_train = vectorizer.fit_transform(X_train)
tf_x_test = vectorizer.transform(X_test)

# %% [markdown]
# #### Modelling

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC(random_state=0)

# %%
clf.fit(tf_x_train,Y_train)
# Out:
# LinearSVC(random_state=0)

# %%
y_test_pred=clf.predict(tf_x_test)

# %% [markdown]
# #### Evaluation

# %%
from sklearn.metrics import classification_report
report=classification_report(Y_test, y_test_pred,output_dict=True)

# %%
report
# Out:
# {'0': {'precision': 0.6543075245365322,
#   'recall': 0.619514713474445,
#   'f1-score': 0.6364359586316627,
#   'support': 1937},
#  '1': {'precision': 0.6235294117647059,
#   'recall': 0.6514822848879248,
#   'f1-score': 0.6371994342291372,
#   'support': 2766},
#  '2': {'precision': 0.7210060549604099,
#   'recall': 0.7140221402214022,
#   'f1-score': 0.7174971031286211,
#   'support': 2168},
#  'accuracy': 0.6622034638335031,
#  'macro avg': {'precision': 0.666280997087216,
#   'recall': 0.6616730461945907,
#   'f1-score': 0.6637108319964736,
#   'support': 6871},
#  'weighted avg': {'precision': 0.6629627645353817,
#   'recall': 0.6622034638335031,
#   'f1-score': 0.6623204492112028,
#   'support': 6871}}
