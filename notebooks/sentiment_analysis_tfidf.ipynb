# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /Users/pawnesh/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/pawnesh/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/pawnesh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/pawnesh/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Importing data

# %%
train_df = pd.read_csv("../datasets/tweet-sentiment-extraction/train.csv")
test_df = pd.read_csv("../datasets/tweet-sentiment-extraction/test.csv")

# %% [markdown]
# ### Data Exploration

# %%
train_df.describe()
# Out:
#             textID                                  text selected_text  \
# count        27481                                 27480         27480
# unique       27481                                 27480         22463
# top     cb774db0d1   I`d have responded, if I were going          good
# freq             1                                     1           199
#
#        sentiment
# count      27481
# unique         3
# top      neutral
# freq       11118

# %%
train_df["text"].describe()
# Out:
# count                                    27480
# unique                                   27480
# top        I`d have responded, if I were going
# freq                                         1
# Name: text, dtype: object

# %%
## Data imbalance check
train_df.sentiment.value_counts()
# Out:
# neutral     11118
# positive     8582
# negative     7781
# Name: sentiment, dtype: int64

# %%
## check text column null row, 
train_df["text"].isnull().values.any()
# Out:
# True

# %%
train_df["text"].isnull().sum()
# Out:
# 1

# %%
# index
train_df[train_df["text"].isnull()].index
# Out:
# Int64Index([314], dtype='int64')

# %%
train_df.iloc[314, :]
# make sense to keep this data
# Out:
# textID           fdb77c3752
# text                    NaN
# selected_text           NaN
# sentiment           neutral
# Name: 314, dtype: object

# %%
train_df["text"].fillna(value="", inplace=True)
train_df["selected_text"].fillna(value="", inplace=True)

# %%
train_df.iloc[314, :]
# Out:
# textID           fdb77c3752
# text
# selected_text
# sentiment           neutral
# Name: 314, dtype: object

# %%
# Convert to lowercase; 
train_df["pre_process"] = train_df["text"].apply(lambda x: " ".join(x.lower() for x in str(x).split()))

# %%
train_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27477  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment  \
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27476                                             d lost  negative
# 27477                                      , don`t force  negative
# 27478                          Yay good for both of you.  positive
# 27479                         But it was worth it  ****.  positive
# 27480  All this flirting going on - The ATG smiles. Y...   neutral
#
#                                              pre_process
# 0                    i`d have responded, if i were going
# 1          sooo sad i will miss you here in san diego!!!
# 2                              my boss is bullying me...
# 3                         what interview! leave me alone
# 4      sons of ****, why couldn`t they put them on th...
# ...                                                  ...
# 27476  wish we could come see u on denver husband los...
# 27477  i`ve wondered about rake to. the client has ma...
# 27478  yay good for both of you. enjoy the break - yo...
# 27479                          but it was worth it ****.
# 27480  all this flirting going on - the atg smiles. y...
#
# [27481 rows x 5 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
train_df['sentiment'] = le.fit_transform(train_df.sentiment.values)

# %%
train_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27477  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text  sentiment  \
# 0                    I`d have responded, if I were going          1
# 1                                               Sooo SAD          0
# 2                                            bullying me          0
# 3                                         leave me alone          0
# 4                                          Sons of ****,          0
# ...                                                  ...        ...
# 27476                                             d lost          0
# 27477                                      , don`t force          0
# 27478                          Yay good for both of you.          2
# 27479                         But it was worth it  ****.          2
# 27480  All this flirting going on - The ATG smiles. Y...          1
#
#                                              pre_process
# 0                    i`d have responded, if i were going
# 1          sooo sad i will miss you here in san diego!!!
# 2                              my boss is bullying me...
# 3                         what interview! leave me alone
# 4      sons of ****, why couldn`t they put them on th...
# ...                                                  ...
# 27476  wish we could come see u on denver husband los...
# 27477  i`ve wondered about rake to. the client has ma...
# 27478  yay good for both of you. enjoy the break - yo...
# 27479                          but it was worth it ****.
# 27480  all this flirting going on - the atg smiles. y...
#
# [27481 rows x 5 columns]

# %%
test_df['sentiment'] = le.transform(test_df.sentiment.values)

# %%
test_df
# Out:
#           textID                                               text  sentiment
# 0     f87dea47db  Last session of the day  http://twitpic.com/67ezh          1
# 1     96d74cb729   Shanghai is also really exciting (precisely -...          2
# 2     eee518ae67  Recession hit Veronique Branquinho, she has to...          0
# 3     01082688c6                                        happy bday!          2
# 4     33987a8ee5             http://twitpic.com/4w75p - I like it!!          2
# ...          ...                                                ...        ...
# 3529  e5f0e6ef4b  its at 3 am, im very tired but i can`t sleep  ...          0
# 3530  416863ce47  All alone in this old house again.  Thanks for...          2
# 3531  6332da480c   I know what you mean. My little dog is sinkin...          0
# 3532  df1baec676  _sutra what is your next youtube video gonna b...          2
# 3533  469e15c5a8   http://twitpic.com/4woj2 - omgssh  ang cute n...          2
#
# [3534 rows x 3 columns]

# %% [markdown]
# #### Removing HTML tags and urls

# %%
from bs4 import BeautifulSoup
train_df["pre_process"]=train_df["pre_process"].apply(lambda x: BeautifulSoup(x).get_text())
import re
train_df["pre_process"]=train_df["pre_process"].apply(lambda x: re.sub(r"http\S+", "", x))
# Out:
# /Users/pawnesh/ws/covid_data_science/covid_19_data_stats/venv/lib/python3.8/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
train_df.sample(10)
# Out:
#            textID                                               text  \
# 9965   a617ec43e3                                         It`s great
# 13882  716bbb29cd  _ci ewww poor you  wish you all the best! than...
# 9960   30116fe6bd   Josh  Excuse me, but, at what time is it goin...
# 3038   1a762a9ca0    haha that was good, slightly geeky but funny  x
# 2002   2cc97395e7                                ughhhh.... sad day.
# 14880  f28af05ca2   Yay! Thank you.. Feels like ur yelling at us ...
# 11459  4e2edbcbab  I`m all stuffted up but I gotta gets up & go n...
# 6083   fdc3815cee            http://twitpic.com/33hus that`s my baby
# 19217  80a43d94a8   Hey JK...Wish Evenlyn a Happy Mothers Day tom...
# 25583  51242b88bf  (SINGZ) SO I THINK IM JST ABT DONE BEING UR GI...
#
#                                            selected_text  sentiment  \
# 9965                                               great          2
# 13882  ewww poor you  wish you all the best! thank Go...          1
# 9960   Josh  Excuse me, but, at what time is it going...          1
# 3038                                               good,          2
# 2002                                                 sad          0
# 14880  Yay! Thank you.. Feels like ur yelling at us   LO          1
# 11459  I`m all stuffted up but I gotta gets up & go n...          1
# 6083             http://twitpic.com/33hus that`s my baby          1
# 19217                                              Happy          2
# 25583  (SINGZ) SO I THINK IM JST ABT DONE BEING UR GI...          1
#
#                                              pre_process
# 9965                                          it`s great
# 13882  _ci ewww poor you wish you all the best! thank...
# 9960   josh excuse me, but, at what time is it going ...
# 3038      haha that was good, slightly geeky but funny x
# 2002                                 ughhhh.... sad day.
# 14880   yay! thank you.. feels like ur yelling at us lol
# 11459  i`m all stuffted up but i gotta gets up & go n...
# 6083                                      that`s my baby
# 19217  hey jk...wish evenlyn a happy mothers day tomo...
# 25583  (singz) so i think im jst abt done being ur gi...

# %% [markdown]
# #### Contraction on text

# %%
def contractions(s):
 s = re.sub(r"won`t", "will not",s)
 s = re.sub(r"would`t", "would not",s)
 s = re.sub(r"could`t", "could not",s)
 s = re.sub(r"\`d", " would",s)
 s = re.sub(r"can\`t", "can not",s)
 s = re.sub(r"n\`t", " not", s)
 s= re.sub(r"\`re", " are", s)
 s = re.sub(r"\`s", " is", s)
 s = re.sub(r"\`ll", " will", s)
 s = re.sub(r"\`t", " not", s)
 s = re.sub(r"\`ve", " have", s)
 s = re.sub(r"\`m", " am", s)
 return s
train_df["pre_process"]=train_df["pre_process"].apply(lambda x:contractions(x))

# %%
train_df.sample(10)
# Out:
#            textID                                               text  \
# 14710  de32b9761a                                         dont quit.
# 7895   d39b91228c   I`ve given the $19.99 question more thought. ...
# 11386  e31563f420   Trickery?  No, just exasperation at seeing **...
# 13873  a5d8cc3057    I`m not even in your situation and now I`m s...
# 26801  6eb6485ae6  i am waaayyyy hungry!  oh fyi my work email is...
# 12695  0759e8d514   When you`re driven to be in the theatre you d...
# 11926  ce26df8553        Facebook Farm town become slower and slower
# 11820  dc027078a1   me.  confused about a guy...he`s great but wh...
# 6147   d073fa9b62  I kind of miss a certain someone already.  and...
# 13215  014a8f6298     We`ll miss you ...   Those lucky Edmontonians!
#
#                                            selected_text  sentiment  \
# 14710                                         dont quit.          1
# 7895                                  t. U may be right.          2
# 11386                                           d uglier          0
# 13873                  . I`m sorry, that`s really sucky.          0
# 26801                                   down again BLAH!          0
# 12695  When you`re driven to be in the theatre you de...          1
# 11926        Facebook Farm town become slower and slower          1
# 11820  me.  confused about a guy...he`s great but why...          1
# 6147   I kind of miss a certain someone already.  and...          1
# 13215                                     We`ll miss you          0
#
#                                              pre_process
# 14710                                         dont quit.
# 7895   i have given the $19.99 question more thought....
# 11386  trickery? no, just exasperation at seeing ****...
# 13873  i am not even in your situation and now i am s...
# 26801  i am waaayyyy hungry! oh fyi my work email is ...
# 12695  when you are driven to be in the theatre you d...
# 11926        facebook farm town become slower and slower
# 11820  me. confused about a guy...he is great but why...
# 6147   i kind of miss a certain someone already. and,...
# 13215     we will miss you ... those lucky edmontonians!

# %% [markdown]
# #### Removing non-alpha words

# %%
train_df["pre_process"]=train_df["pre_process"].apply(lambda x: " ".join([re.sub("[^A-Za-z]+", "", x) for x in nltk.word_tokenize(x)]))

# %%
train_df.sample(10)
# Out:
#            textID                                               text  \
# 21931  130945d03c     SO DO I!!   My jet is in the repair shop...lol
# 5775   aa730765ab   kenny u alive!!!...I`m here getting da hair d...
# 27441  aec8d3c1e5   Wanted to get that piercing too but thought i...
# 6633   cfc7dbb6ee                  aww hope uve hada good day  xxxxx
# 11448  7e795b2ff3   Not doing single ones 2day...beat  lol but wo...
# 1726   da9e839af0   nope not going be able to finish it tonight, ...
# 4078   cfe32cb6f7   hey bettiye,  i did see her. stay tuned for v...
# 17347  15e802cb38                               just finished eating
# 9470   d9ca6707c1    walah me 2 still i am not getting the full idea
# 2732   8a30be8cc7  And i ain`t happy go lucky, its just today... ...
#
#                                            selected_text  sentiment  \
# 21931                                            op...lo          2
# 5775                                               a sad          0
# 27441  Wanted to get that piercing too but thought it...          1
# 6633                            w hope uve hada good day          2
# 11448                                              d fun          2
# 1726   nope not going be able to finish it tonight, g...          1
# 4078   hey bettiye,  i did see her. stay tuned for vi...          1
# 17347                               just finished eating          1
# 9470                         m not getting the full idea          0
# 2732   And i ain`t happy go lucky, its just today... ...          1
#
#                                              pre_process
# 21931        so do i   my jet is in the repair shop  lol
# 5775   kenny u alive     i am here getting da hair do...
# 27441  wanted to get that piercing too but thought it...
# 6633                    aww hope uve hada good day xxxxx
# 11448  not doing single ones day  beat lol but would ...
# 1726   nope not going be able to finish it tonight  g...
# 4078   hey bettiye  i did see her  stay tuned for vid...
# 17347                               just finished eating
# 9470      walah me  still i am not getting the full idea
# 2732   and i ai not happy go lucky  its just today  t...

# %% [markdown]
# #### Removing extra space b/w words

# %%
train_df["pre_process"]=train_df["pre_process"].apply(lambda x: re.sub(" +", " ", x))

# %%
train_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27477  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text  sentiment  \
# 0                    I`d have responded, if I were going          1
# 1                                               Sooo SAD          0
# 2                                            bullying me          0
# 3                                         leave me alone          0
# 4                                          Sons of ****,          0
# ...                                                  ...        ...
# 27476                                             d lost          0
# 27477                                      , don`t force          0
# 27478                          Yay good for both of you.          2
# 27479                         But it was worth it  ****.          2
# 27480  All this flirting going on - The ATG smiles. Y...          1
#
#                                              pre_process
# 0                 i would have responded if i were going
# 1            sooo sad i will miss you here in san diego
# 2                                my boss is bullying me
# 3                          what interview leave me alone
# 4      sons of why could not they put them on the rel...
# ...                                                  ...
# 27476  wish we could come see u on denver husband los...
# 27477  i have wondered about rake to the client has m...
# 27478  yay good for both of you enjoy the break you p...
# 27479                               but it was worth it
# 27480  all this flirting going on the atg smiles yay ...
#
# [27481 rows x 5 columns]

# %% [markdown]
# #### Removing stopwords

# %%
from nltk.corpus import stopwords
stop = stopwords.words("english")
train_df["pre_process"]=train_df["pre_process"].apply(lambda x: " ".join([x for x in x.split() if x not in stop]))

# %%
train_df.sample(10)
# Out:
#            textID                                               text  \
# 6318   3c0e24b99e  My new design portfolio is finally online: htt...
# 10606  a9dd5c8794         Had a great night! Tomorrow is mothers day
# 20425  4ada6dda00  Working from home today, my back is killing me...
# 21900  f8b21ca906           16lbs is still a huge achievement though
# 13630  d05f8cd3cc   yeah ill be on verizon... so those are my two...
# 15895  26ea6f59f0                             @_missrachel how much?
# 7363   a72fd81a70                    don`t care about my struggles..
# 10889  f3b1420f6e  had the best mother`s day! breakfast, shopping...
# 20535  daa3843c18  OMG The LG KC910 touchscreen fone is such a pi...
# 24167  004820461a                      Jacqueline Wilson day on CBBC
#
#                                            selected_text  sentiment  \
# 6318   My new design portfolio is finally online: htt...          1
# 10606                                              great          2
# 20425                                         killing me          0
# 21900                                   huge achievement          2
# 13630  yeah ill be on verizon... so those are my two ...          1
# 15895                             @_missrachel how much?          1
# 7363                     don`t care about my struggles..          0
# 10889                         had the best mother`s day!          2
# 20535                                    pile of shite!!          0
# 24167                      Jacqueline Wilson day on CBBC          1
#
#                                              pre_process
# 6318   new design portfolio finally online still need...
# 10606                   great night tomorrow mothers day
# 20425  working home today back killing doctor physio ...
# 21900                  lbs still huge achievement though
# 13630                 yeah ill verizon two options right
# 15895                                    missrachel much
# 7363                                      care struggles
# 10889  best mother day breakfast shopping lunch drink...
# 20535  omg lg kc touchscreen fone pile shite roll new...
# 24167                         jacqueline wilson day cbbc

# %% [markdown]
# #### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
train_df["pre_process"]=train_df["pre_process"].apply(lambda x: " ".join([lemmatizer.lemmatize(w) for w in nltk.word_tokenize(x)]))

# %%
train_df.sample(10)
# Out:
#            textID                                               text  \
# 5354   b00a057b1a  Haha yea  if i knew yew wanted 2 go i would ha...
# 22320  5328c72bfd   OMG I`M SOO EXCITED! i`ve been waiting for it...
# 20110  b4e7391d34  'Isn`t she lovely? Isn`t she beautiful?' Sorry...
# 2759   c1b8ead73d  My Boy is leaving for the Summer, Going to sta...
# 18714  9b14baf1b9                  urgh, i really hate that medicine
# 26569  93000a69d3                Drinking coffee....MMMMM.....coffee
# 20397  defcb95b1f   yes 7.50 here thanks for the change obama. I ...
# 26421  6b9c032583                         Thanks for making me laugh
# 15063  5c4100c5ac                      Ugh, I hate 90 degree weather
# 1163   2889cb3b49   o can`t work that one out  pain in the **** t...
#
#                                            selected_text  sentiment  \
# 5354   Haha yea  if i knew yew wanted 2 go i would ha...          1
# 22320                               OMG I`M SOO EXCITED!          2
# 20110  you`re not really in a position to make that j...          0
# 2759                                I`m gonna miss him!!          0
# 18714                                               hate          0
# 26569                Drinking coffee....MMMMM.....coffee          1
# 20397  yes 7.50 here thanks for the change obama. I h...          1
# 26421                         Thanks for making me laugh          2
# 15063                                            hate 90          0
# 1163   o can`t work that one out  pain in the **** th...          0
#
#                                              pre_process
# 5354          haha yea knew yew wanted go would told yew
# 22320  omg soo excited waiting ever since saw th one ...
# 20110  lovely beautiful sorry stevie really position ...
# 2759   boy leaving summer going stay grandparent gon ...
# 18714                          urgh really hate medicine
# 26569                       drinking coffee mmmmm coffee
# 20397        yes thanks change obama start mail ordering
# 26421                                thanks making laugh
# 15063                            ugh hate degree weather
# 1163                               work one pain spammer

# %% [markdown]
# #### Data split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train, Y_test = train_test_split(train_df["pre_process"], train_df["sentiment"], test_size=0.25, random_state=30)

# %%
X_train.shape
# Out:
# (20610,)

# %%
Y_train.shape
# Out:
# (20610,)

# %% [markdown]
# #### Token into features with BOW TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer= TfidfVectorizer()
tf_x_train = vectorizer.fit_transform(X_train)
tf_x_test = vectorizer.transform(X_test)

# %% [markdown]
# #### Modelling

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC(random_state=0)

# %%
clf.fit(tf_x_train,Y_train)
# Out:
# LinearSVC(random_state=0)

# %%
y_test_pred=clf.predict(tf_x_test)

# %% [markdown]
# #### Evaluation

# %%
from sklearn.metrics import classification_report
report=classification_report(Y_test, y_test_pred,output_dict=True)

# %%
report
# Out:
# {'0': {'precision': 0.6543075245365322,
#   'recall': 0.619514713474445,
#   'f1-score': 0.6364359586316627,
#   'support': 1937},
#  '1': {'precision': 0.6235294117647059,
#   'recall': 0.6514822848879248,
#   'f1-score': 0.6371994342291372,
#   'support': 2766},
#  '2': {'precision': 0.7210060549604099,
#   'recall': 0.7140221402214022,
#   'f1-score': 0.7174971031286211,
#   'support': 2168},
#  'accuracy': 0.6622034638335031,
#  'macro avg': {'precision': 0.666280997087216,
#   'recall': 0.6616730461945907,
#   'f1-score': 0.6637108319964736,
#   'support': 6871},
#  'weighted avg': {'precision': 0.6629627645353817,
#   'recall': 0.6622034638335031,
#   'f1-score': 0.6623204492112028,
#   'support': 6871}}

# %% [markdown]
# ### Pipeline

# %%
# Todo
